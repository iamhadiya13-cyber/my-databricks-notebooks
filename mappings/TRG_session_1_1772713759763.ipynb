# %% [markdown]
# # ODI to Databricks Migration: Simple HR Employee Insert
#
# **Source File:** `HR_TRG_EMP_INSERT.sql`
# **Conversion Timestamp:** 2024-07-30T12:00:00Z
#
# This notebook converts a simple Oracle ODI INSERT statement for the `TRG_EMP` table into Databricks Spark SQL. It reflects a direct load from the `EMPLOYEES` source table into the target.

# %%
# %sql
-- SCEN_TASK_NO in {10}: Placeholder for initial setup or logging (no SQL provided)
-- SCEN_TASK_NO in {20}: Placeholder for intermediary tasks (no SQL provided)
-- SCEN_TASK_NO in {30}: Insert data into TRG_EMP
INSERT
  INTO workspace.hr.trg_emp
  (
    EMPLOYEE_ID ,
    FIRST_NAME ,
    LAST_NAME ,
    EMAIL ,
    PHONE_NUMBER ,
    HIRE_DATE ,
    JOB_ID ,
    SALARY ,
    COMMISSION_PCT ,
    MANAGER_ID ,
    DEPARTMENT_ID
  )
SELECT
  EMPLOYEES.EMPLOYEE_ID ,
  EMPLOYEES.FIRST_NAME ,
  EMPLOYEES.LAST_NAME ,
  EMPLOYEES.EMAIL ,
  EMPLOYEES.PHONE_NUMBER ,
  EMPLOYEES.HIRE_DATE ,
  EMPLOYEES.JOB_ID ,
  EMPLOYEES.SALARY ,
  EMPLOYEES.COMMISSION_PCT ,
  EMPLOYEES.MANAGER_ID ,
  EMPLOYEES.DEPARTMENT_ID
FROM
  workspace.hr.employees AS EMPLOYEES;

# %% [markdown]
# ## Conversion Notes and Manual Actions
#
# - **Schema Naming:** Original Oracle schema `HR` has been converted to `workspace.hr` as per Databricks naming conventions.
# - **Table Naming:** Table names `TRG_EMP` and `EMPLOYEES` have been converted to lowercase (`trg_emp` and `employees`) and fully qualified with the Databricks schema (`workspace.hr`).
# - **Oracle Hints:** The `/*+ APPEND PARALLEL */` hint has been removed as it is specific to Oracle and not applicable in Spark SQL/Delta Lake environments.
# - **Data Types:** Assumed `workspace.hr.trg_emp` already exists with compatible Spark SQL data types (e.g., `NUMBER` to `BIGINT`/`DECIMAL`, `VARCHAR2` to `STRING`, `DATE` to `TIMESTAMP`). If DDL were provided, explicit type mapping would be applied.
# - **SCEN_TASK_NO:** Tasks {10} and {20} were placeholders without associated SQL and are preserved as comments in the adjacent cell.
# - **No Widgets:** No ODI global or schema parameters (`#GLOBAL.v_...`, `#SCHEMA.v_...`) were identified in the source, so no Databricks widgets were created.
