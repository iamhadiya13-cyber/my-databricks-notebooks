# %% [markdown]
# # ODI to Databricks Migration
#
# ## Target File: `TARGET.sql`
# **Conversion Timestamp**: 2024-07-30T12:00:00Z
#
# ### Description
# This notebook converts an Oracle Data Integrator (ODI) SQL script into a Databricks Spark SQL compatible Jupyter Notebook. It includes the logic for inserting data into the `TRG_LOC` table from `LOCATIONS`.

# %%
# %sql
-- SCEN_TASK_NO in {10}
-- SCEN_TASK_NO in {20}
-- SCEN_TASK_NO in {30}
INSERT INTO workspace.hr.trg_loc
  (
    LOCATION_ID ,
    STREET_ADDRESS ,
    POSTAL_CODE ,
    CITY ,
    STATE_PROVINCE ,
    COUNTRY_ID 
  ) 
SELECT 
  LOCATIONS.LOCATION_ID ,
  LOCATIONS.STREET_ADDRESS ,
  LOCATIONS.POSTAL_CODE ,
  LOCATIONS.CITY ,
  LOCATIONS.STATE_PROVINCE ,
  LOCATIONS.COUNTRY_ID  
FROM 
  workspace.hr.locations AS LOCATIONS;

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
#
# 1.  **Schema and Table Names**: Oracle schema `HR` has been converted to `workspace.hr`. Table names `TRG_LOC` and `LOCATIONS` have been converted to lowercase `trg_loc` and `locations` respectively, following Databricks naming conventions.
# 2.  **`/*+ APPEND PARALLEL */` Hint**: The Oracle-specific `/*+ APPEND PARALLEL */` hint has been removed as it is not applicable in Databricks Spark SQL.
# 3.  **Data Types**: The original DDL for `TRG_LOC` and `LOCATIONS` was not provided. Ensure that the target table `workspace.hr.trg_loc` is created with appropriate Spark SQL data types (e.g., `BIGINT` for `NUMBER(p,0)`-like `LOCATION_ID`, `STRING` for `VARCHAR2`, etc.) before running this insert statement.
# 4.  **SCEN_TASK_NO {10}, {20}, {30}**: These empty or metadata-only SCEN_TASK_NO blocks from the original ODI source have been preserved as comments within the first SQL cell.
