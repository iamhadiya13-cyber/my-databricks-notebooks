# %% [markdown]
# # `TRG_DEP.sql` to Databricks Spark SQL Notebook
#
# **Conversion Timestamp:** 2024-07-30 12:00:00
#
# **Description:** This notebook converts an ODI SQL script for inserting data into the `TRG_DEP` table from `DEPARTMENTS`.

# %%
# %sql
-- SCEN_TASK_NO in {10}

-- SCEN_TASK_NO in {20}

-- SCEN_TASK_NO in {30}

INSERT 
  INTO workspace.hr.trg_dep
  (
    department_id ,
    department_name ,
    manager_id ,
    location_id 
  ) 
SELECT 
  departments.department_id ,
  departments.department_name ,
  departments.manager_id ,
  departments.location_id  
FROM 
  workspace.hr.departments AS departments;

# %% [markdown]
# ## Validation
#
# Confirm record counts after insertion.

# %%
# %sql
SELECT COUNT(*) FROM workspace.hr.trg_dep;

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
#
# - **Schema Mapping:** Original Oracle schema `HR` has been mapped to `workspace.hr`.
# - **Table Naming:** Table names `TRG_DEP` and `DEPARTMENTS` have been converted to lowercase: `trg_dep` and `departments`.
# - **Oracle Hints Removed:** The Oracle hint `/*+ APPEND PARALLEL */` has been removed as it is not applicable in Spark SQL / Delta Lake.
# - **Target Table DDL:** Ensure `workspace.hr.trg_dep` and `workspace.hr.departments` tables exist with compatible schemas in your Databricks environment before running this notebook.
#   - The `TRG_DEP` table is expected to have columns: `department_id`, `department_name`, `manager_id`, `location_id`.
