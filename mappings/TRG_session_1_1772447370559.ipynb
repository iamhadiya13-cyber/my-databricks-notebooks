# %% [markdown]
# # ODI to Databricks Migration: TRG_EMP_INSERT_ONLY
#
# **Conversion Timestamp:** 2024-07-30 12:00:00
#
# **Description:** This notebook converts an ODI integration process for `TRG_EMP` involving a direct insert from `EMPLOYEES` into the target table.
# The original ODI tasks `SCEN_TASK_NO {10}`, `SCEN_TASK_NO {20}`, `SCEN_TASK_NO {30}` are represented by this single insert operation.

# %%
# %sql
-- SCEN_TASK_NO in {10}, {20}, {30}: Insert into target table HR.TRG_EMP
INSERT INTO workspace.hr.trg_emp
  (
    EMPLOYEE_ID ,
    FIRST_NAME ,
    LAST_NAME ,
    EMAIL ,
    PHONE_NUMBER ,
    HIRE_DATE ,
    JOB_ID ,
    SALARY ,
    COMMISSION_PCT ,
    MANAGER_ID ,
    DEPARTMENT_ID 
  ) 
SELECT 
  employees.EMPLOYEE_ID ,
  employees.FIRST_NAME ,
  employees.LAST_NAME ,
  employees.EMAIL ,
  employees.PHONE_NUMBER ,
  employees.HIRE_DATE ,
  employees.JOB_ID ,
  employees.SALARY ,
  employees.COMMISSION_PCT ,
  employees.MANAGER_ID ,
  employees.DEPARTMENT_ID  
FROM 
  workspace.hr.employees AS employees;

# %% [markdown]
# ## Validation

# %%
# %sql
SELECT COUNT(*) FROM workspace.hr.trg_emp;

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
#
# 1.  **Schema and Table Naming:** All schema and table names have been converted to lowercase and prefixed with `workspace.`, e.g., `HR.TRG_EMP` is now `workspace.hr.trg_emp`.
# 2.  **Oracle Hints:** The Oracle-specific hint `/*+ APPEND PARALLEL */` has been removed as it is not applicable in Databricks Spark SQL for Delta tables.
# 3.  **SCEN_TASK_NO:** The ODI `SCEN_TASK_NO {10}`, `SCEN_TASK_NO {20}`, `SCEN_TASK_NO {30}` are typically markers or setup steps in ODI. In this case, they precede a simple `INSERT` operation, which is now the main content of a single SQL cell.
# 4.  **No ODI Parameters:** No `#GLOBAL.` or `#SCHEMA.` parameters were found in the source, so no Databricks widgets were created.
# 5.  **Data Types:** Assuming `workspace.hr.trg_emp` table exists with compatible data types based on the `workspace.hr.employees` source table. No DDL was provided for `TRG_EMP` in the source, so no data type conversions were explicitly applied in the `CREATE TABLE` statements (as none were generated).
