# %% [markdown]
# # ODI to Databricks Migration
# ### File: TARGET.sql
# ### Converted: 2024-07-30 12:00:00
#
# This notebook contains the converted Spark SQL statements from the original ODI SQL file.

# %%
dbutils.widgets.text("ETL_JOB_TYPE", "")
dbutils.widgets.text("DATASOURCE_NUM_ID", "")
dbutils.widgets.text("ETL_PROC_WID", "")
dbutils.widgets.text("ODI_SESS_NO", "")

# %% [markdown]
# ## ETL Parameters

# %%
display(spark.sql("SELECT 'ETL_JOB_TYPE' AS Parameter, '${ETL_JOB_TYPE}' AS Value UNION ALL " +
                  "SELECT 'DATASOURCE_NUM_ID' AS Parameter, '${DATASOURCE_NUM_ID}' AS Value UNION ALL " +
                  "SELECT 'ETL_PROC_WID' AS Parameter, '${ETL_PROC_WID}' AS Value UNION ALL " +
                  "SELECT 'ODI_SESS_NO' AS Parameter, '${ODI_SESS_NO}' AS Value"))

# %%
# %sql
-- SCEN_TASK_NO in {10}
-- SCEN_TASK_NO in {20}
-- SCEN_TASK_NO in {30}
INSERT
  INTO workspace.hr.trg_emp
  (
    EMPLOYEE_ID ,
    FIRST_NAME ,
    LAST_NAME ,
    EMAIL ,
    PHONE_NUMBER ,
    HIRE_DATE ,
    JOB_ID ,
    SALARY ,
    COMMISSION_PCT ,
    MANAGER_ID ,
    DEPARTMENT_ID
  )
SELECT
  EMPLOYEES.EMPLOYEE_ID ,
  EMPLOYEES.FIRST_NAME ,
  EMPLOYEES.LAST_NAME ,
  EMPLOYEES.EMAIL ,
  EMPLOYEES.PHONE_NUMBER ,
  EMPLOYEES.HIRE_DATE ,
  EMPLOYEES.JOB_ID ,
  EMPLOYEES.SALARY ,
  EMPLOYEES.COMMISSION_PCT ,
  EMPLOYEES.MANAGER_ID ,
  EMPLOYEES.DEPARTMENT_ID
FROM
  workspace.hr.employees AS EMPLOYEES;

# %% [markdown]
# ## Cleanup

# %% [markdown]
# ## Validation

# %%
# %sql
SELECT COUNT(*) FROM workspace.hr.trg_emp;

# %% [markdown]
# ### Conversion Notes
# - ODI hints `/*+ APPEND PARALLEL */` have been removed as they are not applicable to Databricks Delta Lake.
# - Schema and table names converted to lowercase and prefixed with `workspace.`.
# - No ODI parameters found in the original source, so standard Databricks widgets for common ETL parameters are created as placeholders.
# - `SCEN_TASK_NO` entries {10}, {20}, {30} were empty in the source and are preserved as comments within the relevant SQL cell.
