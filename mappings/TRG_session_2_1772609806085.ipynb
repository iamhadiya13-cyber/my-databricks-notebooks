# %% [markdown]
# # ODI to Databricks Migration
#
# ## Source File: TRG_DEP_INSERT.sql
# **Conversion Timestamp:** 2024-07-30 12:00:00 UTC
#
# **Description:** This notebook converts an ODI `INSERT` statement for the `TRG_DEP` table from Oracle SQL to Databricks Spark SQL. It handles schema and table naming conventions and removes Oracle-specific hints.

# %%
# %sql
-- SCEN_TASK_NO in {10}
-- SCEN_TASK_NO in {20}
-- SCEN_TASK_NO in {30}
INSERT INTO workspace.hr.trg_dep
(
  department_id,
  department_name,
  manager_id,
  location_id
)
SELECT
  departments.department_id,
  departments.department_name,
  departments.manager_id,
  departments.location_id
FROM
  workspace.hr.departments AS departments;

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
#
# 1.  **Schema and Table Naming:** Oracle schema `HR` and table names `TRG_DEP`, `DEPARTMENTS` have been converted to lowercase and prefixed with `workspace.` as `workspace.hr.trg_dep` and `workspace.hr.departments` respectively.
# 2.  **Oracle Hints Removal:** The Oracle-specific `/*+ APPEND PARALLEL */` hint has been removed as it is not applicable in Databricks Spark SQL.
# 3.  **Data Types:** No DDL was provided in the source file, so it's assumed the target table `workspace.hr.trg_dep` already exists with compatible Spark SQL data types (e.g., `BIGINT` for `NUMBER(p,0)`, `STRING` for `VARCHAR2`, etc.). If not, a `CREATE TABLE` statement with appropriate Spark types would be required before this insert.
# 4.  **Widget Parameters:** No `#GLOBAL.` or `#SCHEMA.` parameters were found in the source SQL snippet, so no Databricks widgets or temporary views for parameters (`v_etl_last_extract_time`, etc.) have been generated in this notebook.
# 5.  **Performance:** For large inserts, Databricks Delta Lake inherently optimizes writes. No specific performance tuning (like `OPTIMIZE`) has been added for this simple insert, but it might be considered for a full ETL flow.
