# %% [markdown]
# # trg_loc.sql Conversion
#
# **Conversion Date**: 2024-07-30
#
# **Description**: This notebook converts the ODI SQL for the `TRG_LOC` table into Databricks Spark SQL. It performs a full load insert from the `LOCATIONS` source table into `TRG_LOC`.
#
# **Source ODI SCEN_TASK_NOs Covered**:
# - SCEN_TASK_NO in {10}: (No-op / session marker)
# - SCEN_TASK_NO in {20}: (No-op / session marker)
# - SCEN_TASK_NO in {30}: (No-op / session marker)
# - Insert into HR.TRG_LOC

# %%
# %sql
INSERT INTO workspace.hr.trg_loc
  (
    LOCATION_ID ,
    STREET_ADDRESS ,
    POSTAL_CODE ,
    CITY ,
    STATE_PROVINCE ,
    COUNTRY_ID 
  ) 
SELECT 
  LOCATIONS.LOCATION_ID ,
  LOCATIONS.STREET_ADDRESS ,
  LOCATIONS.POSTAL_CODE ,
  LOCATIONS.CITY ,
  LOCATIONS.STATE_PROVINCE ,
  LOCATIONS.COUNTRY_ID  
FROM 
  workspace.hr.locations AS LOCATIONS;
