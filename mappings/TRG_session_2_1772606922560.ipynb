# %% [markdown]
# # HR to TRG_DEP Data Load
#
# **Conversion Timestamp**: 2024-05-16 12:00:00 UTC
#
# This notebook loads data from the `HR.DEPARTMENTS` table into `HR.TRG_DEP`.

# %%
# %sql
-- SCEN_TASK_NO {10}: (No operation in source, placeholder)
-- SCEN_TASK_NO {20}: (No operation in source, placeholder)
-- SCEN_TASK_NO {30}: (No operation in source, placeholder)

-- Create the target table if it does not exist.
-- Inferred DDL based on common Oracle HR.DEPARTMENTS table structure.
CREATE TABLE IF NOT EXISTS workspace.hr.trg_dep (
    DEPARTMENT_ID   BIGINT,
    DEPARTMENT_NAME STRING,
    MANAGER_ID      BIGINT,
    LOCATION_ID     BIGINT
) USING DELTA;

# %%
# %sql
INSERT INTO workspace.hr.trg_dep
(
  DEPARTMENT_ID ,
  DEPARTMENT_NAME ,
  MANAGER_ID ,
  LOCATION_ID
)
SELECT
  departments.department_id ,
  departments.department_name ,
  departments.manager_id ,
  departments.location_id
FROM
  workspace.hr.departments AS departments;

# %%
# %sql
SELECT COUNT(*) FROM workspace.hr.trg_dep;

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
#
# *   **Schema Mapping**: The original Oracle schema `HR` has been mapped to `workspace.hr`.
# *   **Table Naming**: Table names `TRG_DEP` and `DEPARTMENTS` have been converted to lowercase `trg_dep` and `departments`.
# *   **Oracle Hints**: The `/*+ APPEND PARALLEL */` hint has been removed as it is not applicable in Databricks Spark SQL for Delta tables.
# *   **DDL Inference**: The `CREATE TABLE IF NOT EXISTS workspace.hr.trg_dep` statement was inferred based on the `INSERT` statement's column list and typical Oracle HR schema types. It is recommended to verify the inferred data types (`BIGINT`, `STRING`) against the actual source DDL and adjust if necessary, especially for precision/scale of numeric types.
# *   **Empty SCEN_TASK_NO Blocks**: Original ODI tasks {10}, {20}, {30} contained no executable SQL and have been included as comments in the first SQL cell for context.
