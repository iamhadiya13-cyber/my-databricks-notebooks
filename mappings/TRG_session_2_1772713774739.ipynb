# %% [markdown]
# # ODI to Databricks Migration: `insert_trg_dep.txt`
#
# **Conversion Timestamp:** 2024-07-30T12:00:00Z
#
# **Description:** This notebook loads data from the `DEPARTMENTS` table into `TRG_DEP`.

# %%
# Define ETL parameters as widgets (no specific parameters found in source, but cell retained as per template)
dbutils.widgets.text("ETL_JOB_TYPE", "FULL")
dbutils.widgets.text("DATASOURCE_NUM_ID", "1")
dbutils.widgets.text("ETL_PROC_WID", "-1")
dbutils.widgets.text("ODI_SESS_NO", "-1")

# %% [markdown]
# ## ETL Parameters

# %%
# %sql
SELECT
  '${ETL_JOB_TYPE}' AS ETL_JOB_TYPE,
  '${DATASOURCE_NUM_ID}' AS DATASOURCE_NUM_ID,
  '${ETL_PROC_WID}' AS ETL_PROC_WID,
  '${ODI_SESS_NO}' AS ODI_SESS_NO;

# %% [markdown]
# ## Target Table DDL

# %%
# %sql
-- SCEN_TASK_NO in {10}: Placeholder for potential setup tasks
-- SCEN_TASK_NO in {20}: Placeholder for potential setup tasks
-- SCEN_TASK_NO in {30}: Placeholder for potential setup tasks

CREATE TABLE IF NOT EXISTS workspace.hr.trg_dep (
    DEPARTMENT_ID   BIGINT,
    DEPARTMENT_NAME STRING,
    MANAGER_ID      BIGINT,
    LOCATION_ID     BIGINT
) USING DELTA;

# %% [markdown]
# ## Load Data

# %%
# %sql
-- SCEN_TASK_NO in {10}
-- SCEN_TASK_NO in {20}
-- SCEN_TASK_NO in {30}

INSERT INTO workspace.hr.trg_dep (
    DEPARTMENT_ID,
    DEPARTMENT_NAME,
    MANAGER_ID,
    LOCATION_ID
)
SELECT
    departments.department_id,
    departments.department_name,
    departments.manager_id,
    departments.location_id
FROM
    workspace.hr.departments AS departments;

# %% [markdown]
# ## Validation

# %%
# %sql
SELECT COUNT(*) FROM workspace.hr.trg_dep;

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
#
# - **Schema and Table Naming:** All Oracle schema (`HR`) and table names (`TRG_DEP`, `DEPARTMENTS`) have been converted to lowercase and prefixed with `workspace.` (e.g., `workspace.hr.trg_dep`, `workspace.hr.departments`).
# - **Oracle Hints:** The `/*+ APPEND PARALLEL */` hint has been removed as it is not applicable to Databricks Delta Lake.
# - **Data Types:** Oracle `NUMBER` types have been inferred as `BIGINT` and `VARCHAR2` as `STRING` for the `CREATE TABLE` statement based on common HR schema definitions. Please verify these mappings against your actual source Oracle DDL.
# - **SCEN_TASK_NO:** Generic `SCEN_TASK_NO` entries without associated SQL statements have been included as comments in adjacent SQL cells to maintain context.
# - **Widgets:** Placeholder `dbutils` widgets for common ETL parameters have been created, as per the template, even though no direct ODI parameters (`#GLOBAL.`, `#SCHEMA.`) were found in the source SQL for this specific file. These can be removed if not needed for overall orchestration.
