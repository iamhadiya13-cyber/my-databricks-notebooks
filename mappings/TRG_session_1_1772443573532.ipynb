# %% [markdown]
# # ODI to Databricks Migration: TRG_EMP
#
# **Conversion Timestamp:** 2024-07-30 12:00:00
#
# **Description:** This notebook loads data into the `TRG_EMP` target table from the `EMPLOYEES` source table.
#
# This is a direct insert flow.

# %%
# Create ETL parameter widgets (as per conversion template)
dbutils.widgets.text("ETL_JOB_TYPE", "", "ETL Job Type");
dbutils.widgets.text("DATASOURCE_NUM_ID", "", "Datasource Number ID");
dbutils.widgets.text("ETL_PROC_WID", "", "ETL Process ID");
dbutils.widgets.text("ODI_SESS_NO", "", "ODI Session Number");

# Note: This specific ODI SQL does not use these parameters, but they are included as per the standard template.

# %% [markdown]
# ## ETL Parameters

# %%
display(spark.sql("""
  SELECT
    '${ETL_JOB_TYPE}' AS ETL_JOB_TYPE,
    '${DATASOURCE_NUM_ID}' AS DATASOURCE_NUM_ID,
    '${ETL_PROC_WID}' AS ETL_PROC_WID,
    '${ODI_SESS_NO}' AS ODI_SESS_NO
"""))

# %% [markdown]
# ## Staging Table (C$)
#
# *(Note: C$ staging tables are not explicitly used or created in this particular ODI flow. If they were, this section would contain their DDL and INSERT statements.)*

# %% [markdown]
# ## Flow Table (I$)
#
# *(Note: I$ flow tables are not explicitly used or created in this particular ODI flow. If they were, this section would contain their DDL and INSERT statements.)*

# %% [markdown]
# ## Error / Check Tables (E$, SNP_CHECK_TAB)
#
# *(Note: Error and check tables are not explicitly used or created in this particular ODI flow. If they were, this section would contain their DDL and related DML.)*

# %% [markdown]
# ## Load Target Table

# %%
# %sql
-- SCEN_TASK_NO in {10}: (No SQL provided for this task)

-- SCEN_TASK_NO in {20}: (No SQL provided for this task)

-- SCEN_TASK_NO in {30}: (No SQL provided for this task)

INSERT INTO workspace.hr.trg_emp (
    EMPLOYEE_ID ,
    FIRST_NAME ,
    LAST_NAME ,
    EMAIL ,
    PHONE_NUMBER ,
    HIRE_DATE ,
    JOB_ID ,
    SALARY ,
    COMMISSION_PCT ,
    MANAGER_ID ,
    DEPARTMENT_ID
)
SELECT
    EMPLOYEES.EMPLOYEE_ID ,
    EMPLOYEES.FIRST_NAME ,
    EMPLOYEES.LAST_NAME ,
    EMPLOYEES.EMAIL ,
    EMPLOYEES.PHONE_NUMBER ,
    EMPLOYEES.HIRE_DATE ,
    EMPLOYEES.JOB_ID ,
    EMPLOYEES.SALARY ,
    EMPLOYEES.COMMISSION_PCT ,
    EMPLOYEES.MANAGER_ID ,
    EMPLOYEES.DEPARTMENT_ID
FROM
    workspace.hr.employees AS EMPLOYEES;

# %% [markdown]
# ## Optimize Target
#
# *(Note: No explicit `OPTIMIZE` or `ZORDER BY` statements were present in the original ODI flow. It is recommended to add these based on query patterns for performance.)*

# %% [markdown]
# ## Cleanup
#
# *(Note: No temporary ODI C$ or I$ tables were created in this flow that require cleanup.)*

# %% [markdown]
# ## Validation
#
# *(Note: This section would typically contain queries to validate record counts, data integrity, and error table summaries.)*

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
#
# 1.  **Schema and Table Names:** All schema and table names (`HR.TRG_EMP`, `HR.EMPLOYEES`) have been converted to lowercase and prefixed with `workspace.` (e.g., `workspace.hr.trg_emp`, `workspace.hr.employees`).
# 2.  **Oracle Hints:** The Oracle `/*+ APPEND PARALLEL */` hint has been removed as it is not applicable in Databricks Delta Lake.
# 3.  **Data Types:** Assuming the target table `workspace.hr.trg_emp` is created with compatible Spark SQL data types (e.g., `BIGINT` for `EMPLOYEE_ID`, `STRING` for `FIRST_NAME`, `TIMESTAMP` for `HIRE_DATE`, `DECIMAL` or `DOUBLE` for `SALARY`). If the target table does not exist, a `CREATE TABLE` DDL statement should be added to the notebook prior to this `INSERT` statement.
# 4.  **ETL Parameters:** Although the standard ETL parameter widgets (`ETL_JOB_TYPE`, `DATASOURCE_NUM_ID`, `ETL_PROC_WID`, `ODI_SESS_NO`) are created, they are not referenced in the provided SQL. This conversion assumes they are part of a broader ETL framework and kept for consistency.
# 5.  **Task Numbers:** `SCEN_TASK_NO` entries {10}, {20}, {30} had no associated SQL in the original source and are noted as comments.
