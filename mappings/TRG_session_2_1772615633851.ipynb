# %% [markdown]
# # `TRG_DEP_Load.sql` Conversion**Converted On:** 2024-07-30This notebook converts the ODI SQL `TRG_DEP_Load.sql` into Databricks Spark SQL. It handles a simple direct insert into the `TRG_DEP` table from the `DEPARTMENTS` source table.

# %%
dbutils.widgets.text("ETL_JOB_TYPE", "", "ETL Job Type (e.g., I for incremental)")
dbutils.widgets.text("DATASOURCE_NUM_ID", "", "Datasource Number ID")
dbutils.widgets.text("ETL_PROC_WID", "", "ETL Process Widget ID")
dbutils.widgets.text("ODI_SESS_NO", "", "ODI Session Number")

# %% [markdown]
# # ETL Parameters

# %%
print(f"ETL_JOB_TYPE: {dbutils.widgets.get('ETL_JOB_TYPE')}")
print(f"DATASOURCE_NUM_ID: {dbutils.widgets.get('DATASOURCE_NUM_ID')}")
print(f"ETL_PROC_WID: {dbutils.widgets.get('ETL_PROC_WID')}")
print(f"ODI_SESS_NO: {dbutils.widgets.get('ODI_SESS_NO')}")

# %% [markdown]
# # Data Loading

# %%
# %sql
-- SCEN_TASK_NO in {30}: Insert into target table
INSERT
  INTO workspace.hr.trg_dep
  (
    DEPARTMENT_ID ,
    DEPARTMENT_NAME ,
    MANAGER_ID ,
    LOCATION_ID
  )
SELECT
  DEPARTMENTS.DEPARTMENT_ID ,
  DEPARTMENTS.DEPARTMENT_NAME ,
  DEPARTMENTS.MANAGER_ID ,
  DEPARTMENTS.LOCATION_ID
FROM
  workspace.hr.departments AS DEPARTMENTS;

# %% [markdown]
# # Validation

# %%
# %sql
SELECT COUNT(*) AS total_records FROM workspace.hr.trg_dep;

# %% [markdown]
# # Conversion Notes1.  **Schema and Table Naming:** Original Oracle schema `HR` has been converted to `workspace.hr`. Table names `TRG_DEP` and `DEPARTMENTS` have been converted to lowercase: `trg_dep` and `departments` respectively.2.  **Oracle Hints:** The `/*+ APPEND PARALLEL */` hint, which is Oracle-specific for direct-path inserts, has been removed as it is not applicable in Databricks Spark SQL.3.  **SCEN_TASK_NO:** The `SCEN_TASK_NO` comments indicate original ODI task numbering. Only the relevant task for the SQL statement is kept as a comment in the corresponding cell. Empty task blocks are omitted.4.  **No complex logic:** The original snippet contained only a simple INSERT statement, so no complex conversions (e.g., MERGE, NVL, TO_TIMESTAMP, ROW_NUMBER) were required for the SQL logic itself.
