# %% [markdown]
# # ODI to Databricks Migration: TRG_EMP_Load
#
# **Conversion Timestamp:** 2024-07-30 12:00:00 UTC
#
# **Description:** This notebook loads data from `workspace.hr.employees` into `workspace.hr.trg_emp`.

# %% [markdown]
# ## Load into Target Table

# %%
# %sql
-- SCEN_TASK_NO in {10}
-- SCEN_TASK_NO in {20}
-- SCEN_TASK_NO in {30}
INSERT
  INTO workspace.hr.trg_emp
  (
    EMPLOYEE_ID ,
    FIRST_NAME ,
    LAST_NAME ,
    EMAIL ,
    PHONE_NUMBER ,
    HIRE_DATE ,
    JOB_ID ,
    SALARY ,
    COMMISSION_PCT ,
    MANAGER_ID ,
    DEPARTMENT_ID
  )
SELECT
  EMPLOYEES.EMPLOYEE_ID ,
  EMPLOYEES.FIRST_NAME ,
  EMPLOYEES.LAST_NAME ,
  EMPLOYEES.EMAIL ,
  EMPLOYEES.PHONE_NUMBER ,
  EMPLOYEES.HIRE_DATE ,
  EMPLOYEES.JOB_ID ,
  EMPLOYEES.SALARY ,
  EMPLOYEES.COMMISSION_PCT ,
  EMPLOYEES.MANAGER_ID ,
  EMPLOYEES.DEPARTMENT_ID
FROM
  workspace.hr.employees AS EMPLOYEES;

# %%
# %sql
SELECT COUNT(*) AS target_record_count FROM workspace.hr.trg_emp;

# %% [markdown]
# ## Validation

# %%
# %sql
SELECT * FROM workspace.hr.trg_emp LIMIT 10;

# %% [markdown]
# ## Conversion Notes
#
# - The Oracle `/*+ APPEND PARALLEL */` hint has been removed as it is not applicable in Databricks Delta Lake.
# - Schema `HR` has been converted to `workspace.hr`.
# - Table names `TRG_EMP` and `EMPLOYEES` have been converted to lowercase (`trg_emp`, `employees`) for consistency with Databricks naming conventions.
# - This conversion assumed `TRG_EMP` is a pre-existing table. If `TRG_EMP` is not yet created, a `CREATE TABLE` DDL statement should be added before this `INSERT`.
