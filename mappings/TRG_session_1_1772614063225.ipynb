# %% [markdown]
# # ODI to Databricks Migration
#
# **Source File:** `TARGET.sql`
# **Conversion Timestamp:** 2024-07-30 12:00:00 UTC
#
# ## Description
# This notebook contains the conversion of an ODI SQL insert statement to load data into the `TRG_EMP` table from the `EMPLOYEES` table.

# %% [markdown]
# ## Target Table Load

# %%
# %sql
-- SCEN_TASK_NO in {10}: Initial setup or variable declaration (no SQL provided)
-- SCEN_TASK_NO in {20}: Additional setup or variable declaration (no SQL provided)
-- SCEN_TASK_NO in {30}: Insert into TRG_EMP
INSERT INTO workspace.hr.trg_emp
  (
    EMPLOYEE_ID ,
    FIRST_NAME ,
    LAST_NAME ,
    EMAIL ,
    PHONE_NUMBER ,
    HIRE_DATE ,
    JOB_ID ,
    SALARY ,
    COMMISSION_PCT ,
    MANAGER_ID ,
    DEPARTMENT_ID
  )
SELECT
  EMPLOYEES.EMPLOYEE_ID ,
  EMPLOYEES.FIRST_NAME ,
  EMPLOYEES.LAST_NAME ,
  EMPLOYEES.EMAIL ,
  EMPLOYEES.PHONE_NUMBER ,
  EMPLOYEES.HIRE_DATE ,
  EMPLOYEES.JOB_ID ,
  EMPLOYEES.SALARY ,
  EMPLOYEES.COMMISSION_PCT ,
  EMPLOYEES.MANAGER_ID ,
  EMPLOYEES.DEPARTMENT_ID
FROM
  workspace.hr.employees AS EMPLOYEES;

# %% [markdown]
# ## Validation

# %%
# %sql
SELECT COUNT(*) FROM workspace.hr.trg_emp;

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
#
# 1.  **Table Existence:** This notebook assumes that `workspace.hr.trg_emp` and `workspace.hr.employees` tables already exist with compatible schemas. If `trg_emp` does not exist, a `CREATE TABLE` DDL statement would be required before this `INSERT`. The DDL for `trg_emp` was not provided in the source SQL, so it's omitted here.
# 2.  **Schema and Naming:** Oracle schema `HR` has been converted to `workspace.hr` and table names to lowercase (`trg_emp`, `employees`) as per migration rules.
# 3.  **Performance Hints:** Oracle-specific hints like `/*+ APPEND PARALLEL */` have been removed as they are not applicable to Databricks Spark SQL and Delta Lake.
