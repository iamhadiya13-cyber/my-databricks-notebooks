# %% [markdown]
# # simple_full_load.txt Conversion
# Converted on 2023-10-27 10:00:00
#
# This notebook performs a full load INSERT from the `employees` table to the `trg_emp` target table within the `HR` schema.

# %% [markdown]
# ## SCEN_TASK_NO Details
#
# The following conceptual steps are identified in the original ODI source:
# *   SCEN_TASK_NO {10}
# *   SCEN_TASK_NO {20}
# *   SCEN_TASK_NO {30}
#
# The DML statements for data loading follow these conceptual steps.

# %%
# %sql
INSERT 
  INTO workspace.hr.trg_emp
  (
    EMPLOYEE_ID ,
    FIRST_NAME ,
    LAST_NAME ,
    EMAIL ,
    PHONE_NUMBER ,
    HIRE_DATE ,
    JOB_ID ,
    SALARY ,
    COMMISSION_PCT ,
    MANAGER_ID ,
    DEPARTMENT_ID 
  ) 
SELECT 
  EMPLOYEES.EMPLOYEE_ID ,
  EMPLOYEES.FIRST_NAME ,
  EMPLOYEES.LAST_NAME ,
  EMPLOYEES.EMAIL ,
  EMPLOYEES.PHONE_NUMBER ,
  EMPLOYEES.HIRE_DATE ,
  EMPLOYEES.JOB_ID ,
  EMPLOYEES.SALARY ,
  EMPLOYEES.COMMISSION_PCT ,
  EMPLOYEES.MANAGER_ID ,
  EMPLOYEES.DEPARTMENT_ID  
FROM 
  workspace.hr.employees AS EMPLOYEES;

# %% [markdown]
# ## Validation
#
# No specific validation steps were provided in the original ODI script for this task. Consider adding `SELECT COUNT(*) FROM workspace.hr.trg_emp;` to verify data load.

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
#
# *   **Schema and Table Naming**: Oracle schema `HR` has been converted to `workspace.hr`. Table names `TRG_EMP` and `EMPLOYEES` have been converted to lowercase `trg_emp` and `employees` respectively.
# *   **Oracle Hints**: The Oracle hint `/*+ APPEND PARALLEL */` was removed as it is not applicable in Databricks Spark SQL and Delta Lake.
# *   **Table Existence**: This script assumes the target table `workspace.hr.trg_emp` already exists with the correct schema and data types. If not, a `CREATE TABLE` DDL statement for `trg_emp` should be added prior to the INSERT statement, ensuring Oracle data types are mapped correctly to Spark SQL (e.g., `NUMBER` to `BIGINT`/`DECIMAL`, `VARCHAR2` to `STRING`, `DATE` to `TIMESTAMP`).
