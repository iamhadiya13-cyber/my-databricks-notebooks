# %% [markdown]
# # ODI to Databricks Migration: `TRG_EMP` Full Load
#
# **Conversion Timestamp**: 2024-07-30T12:00:00Z
#
# This notebook performs a full load insert into the `TRG_EMP` table from the `EMPLOYEES` source table.

# %%
# %sql
-- SCEN_TASK_NO in {10}: Initial Task (no SQL provided in source)

-- SCEN_TASK_NO in {20}: Second Task (no SQL provided in source)

-- SCEN_TASK_NO in {30}: Third Task (no SQL provided in source)
-- This task likely involved truncating or deleting from the target table before the insert for a full load scenario.

INSERT
  INTO workspace.hr.trg_emp
  (
    employee_id ,
    first_name ,
    last_name ,
    email ,
    phone_number ,
    hire_date ,
    job_id ,
    salary ,
    commission_pct ,
    manager_id ,
    department_id
  )
SELECT
  EMPLOYEES.EMPLOYEE_ID ,
  EMPLOYEES.FIRST_NAME ,
  EMPLOYEES.LAST_NAME ,
  EMPLOYEES.EMAIL ,
  EMPLOYEES.PHONE_NUMBER ,
  EMPLOYEES.HIRE_DATE ,
  EMPLOYEES.JOB_ID ,
  EMPLOYEES.SALARY ,
  EMPLOYEES.COMMISSION_PCT ,
  EMPLOYEES.MANAGER_ID ,
  EMPLOYEES.DEPARTMENT_ID
FROM
  workspace.hr.employees AS EMPLOYEES;
