# %% [markdown]
# # ODI to Databricks Migration: `TRG_EMP_direct_insert`
#
# **Conversion Timestamp:** 2024-07-30 12:00:00
#
# **Description:** This notebook performs a direct insert from the `employees` source table to the `trg_emp` target table in the `hr` schema.

# %%
# %sql
-- SCEN_TASK_NO in {10}
-- SCEN_TASK_NO in {20}
-- SCEN_TASK_NO in {30}
INSERT
  INTO workspace.hr.trg_emp
  (
    EMPLOYEE_ID ,
    FIRST_NAME ,
    LAST_NAME ,
    EMAIL ,
    PHONE_NUMBER ,
    HIRE_DATE ,
    JOB_ID ,
    SALARY ,
    COMMISSION_PCT ,
    MANAGER_ID ,
    DEPARTMENT_ID
  )
SELECT
  EMPLOYEES.EMPLOYEE_ID ,
  EMPLOYEES.FIRST_NAME ,
  EMPLOYEES.LAST_NAME ,
  EMPLOYEES.EMAIL ,
  EMPLOYEES.PHONE_NUMBER ,
  EMPLOYEES.HIRE_DATE ,
  EMPLOYEES.JOB_ID ,
  EMPLOYEES.SALARY ,
  EMPLOYEES.COMMISSION_PCT ,
  EMPLOYEES.MANAGER_ID ,
  EMPLOYEES.DEPARTMENT_ID
FROM
  workspace.hr.employees AS EMPLOYEES;

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
#
# 1.  **Schema and Table Naming:** Oracle schema `HR` converted to `workspace.hr`. Table names `TRG_EMP` and `EMPLOYEES` converted to lowercase: `trg_emp` and `employees`.
# 2.  **Oracle Hints:** The Oracle hints `/*+ APPEND PARALLEL */` have been removed as they are not applicable to Databricks Delta Lake.
# 3.  **Direct Insert:** This notebook performs a direct `INSERT` into `workspace.hr.trg_emp`. Ensure that the `trg_emp` table exists and has the correct schema (column names and data types) matching the `employees` source table for a successful insert.
# 4.  **Missing DDL:** The original ODI source only provided an `INSERT` statement, without any `CREATE TABLE` DDL for `TRG_EMP`. The target table `workspace.hr.trg_emp` is assumed to exist with a compatible schema. If it does not exist, manual creation of the table with appropriate data types based on the `employees` source table will be required before running this notebook.
# 5.  **No ODI Parameters:** The original SQL did not contain any ODI `#GLOBAL` or `#SCHEMA` parameters, so no Databricks widgets were created.
# 6.  **No Staging/Flow/Error Tables:** The original SQL was a simple direct insert, so no C$, I$, or E$ tables, or associated cleanup/error handling logic, were generated.
