# %% [markdown]
# # ODI to Databricks Migration: TRG_DEP_Load
#
# **Source File:** `TRG_DEP_Load.txt`
# **Conversion Timestamp:** 2024-07-30
# **Description:** This notebook loads data into the `trg_dep` table from the `departments` source table.

# %% [markdown]
# ## Initial Steps
#
# The following SCEN_TASK_NO blocks were present in the source but did not contain executable SQL statements:
# - SCEN_TASK_NO {10}
# - SCEN_TASK_NO {20}
# - SCEN_TASK_NO {30}

# %%
# %sql
INSERT INTO workspace.hr.trg_dep (
    DEPARTMENT_ID,
    DEPARTMENT_NAME,
    MANAGER_ID,
    LOCATION_ID
)
SELECT
    departments.DEPARTMENT_ID,
    departments.DEPARTMENT_NAME,
    departments.MANAGER_ID,
    departments.LOCATION_ID
FROM
    workspace.hr.departments AS departments;

# %% [markdown]
# ## Cleanup
#
# No temporary staging or flow tables were used in this process, so no explicit cleanup is required.

# %% [markdown]
# ## Validation

# %%
# %sql
SELECT COUNT(*) AS total_records_in_target
FROM workspace.hr.trg_dep;

# %% [markdown]
# ## Conversion Notes
#
# - Oracle schema `HR` converted to `workspace.hr`.
# - Oracle table names `TRG_DEP` and `DEPARTMENTS` converted to lowercase `trg_dep` and `departments`.
# - `/*+ APPEND PARALLEL */` hint removed as it is specific to Oracle and not applicable to Databricks Delta Lake.
# - No ETL parameters (`#GLOBAL` or `#SCHEMA`) were detected in the source, so no widgets were created.
# - Empty `SCEN_TASK_NO` blocks ({10}, {20}, {30}) were noted in a markdown cell, as they contained no executable SQL.
