# %% [markdown]
# # ODI to Databricks Spark SQL Conversion
#
# ## File: SCEN_TASK_NO in {10}, {20}, {30} - HR.TRG_EMP INSERT
#
# **Conversion Timestamp:** 2024-07-30 12:00:00
#
# This notebook contains the converted Spark SQL for the ODI scenario, performing a direct insert into the `trg_emp` table from `employees`.

# %%
# %sql
-- SCEN_TASK_NO in {10}
-- SCEN_TASK_NO in {20}
-- SCEN_TASK_NO in {30}
INSERT INTO workspace.hr.trg_emp
  (
    EMPLOYEE_ID ,
    FIRST_NAME ,
    LAST_NAME ,
    EMAIL ,
    PHONE_NUMBER ,
    HIRE_DATE ,
    JOB_ID ,
    SALARY ,
    COMMISSION_PCT ,
    MANAGER_ID ,
    DEPARTMENT_ID
  )
SELECT
  EMPLOYEES.EMPLOYEE_ID ,
  EMPLOYEES.FIRST_NAME ,
  EMPLOYEES.LAST_NAME ,
  EMPLOYEES.EMAIL ,
  EMPLOYEES.PHONE_NUMBER ,
  EMPLOYEES.HIRE_DATE ,
  EMPLOYEES.JOB_ID ,
  EMPLOYEES.SALARY ,
  EMPLOYEES.COMMISSION_PCT ,
  EMPLOYEES.MANAGER_ID ,
  EMPLOYEES.DEPARTMENT_ID
FROM
  workspace.hr.employees AS EMPLOYEES;

# %% [markdown]
# ## Validation

# %%
# %sql
SELECT COUNT(*) AS total_records_inserted
FROM workspace.hr.trg_emp;

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
#
# 1.  **Oracle Hints Removed:** The `/*+ APPEND PARALLEL */` hint has been removed as it is specific to Oracle and not applicable to Databricks Delta Lake.
# 2.  **Schema and Table Naming:** Oracle schema `HR` and table names `TRG_EMP`, `EMPLOYEES` have been converted to lowercase and prefixed with `workspace.` (e.g., `HR.TRG_EMP` -> `workspace.hr.trg_emp`).
# 3.  **Data Types:** The `INSERT` statement does not explicitly define column data types. Ensure that the target table `workspace.hr.trg_emp` is created with appropriate Spark SQL data types (e.g., `NUMBER(p,0)` -> `BIGINT`, `VARCHAR2` -> `STRING`, `DATE` -> `TIMESTAMP`). This is a direct `SELECT *` style insert, so column types are inferred from the source table `workspace.hr.employees` or must match the target.
# 4.  **No Parameters:** No ODI `#GLOBAL` or `#SCHEMA` parameters were detected in the source SQL, so no Databricks widgets were created.
