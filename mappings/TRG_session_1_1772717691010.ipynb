# %% [markdown]
# # ODI to Databricks Migration
#
# ## File: TARGET.sql
# **Conversion Timestamp:** 2024-07-29 12:00:00
#
# This notebook contains the conversion of a simple Oracle ODI INSERT statement to Databricks Spark SQL. The original file consists of a direct load from the `EMPLOYEES` table to `TRG_EMP`.

# %% [markdown]
# ## SCEN_TASK_NO {30}: Insert into Target Table

# %%
# %sql
INSERT INTO workspace.hr.trg_emp
  (
    employee_id ,
    first_name ,
    last_name ,
    email ,
    phone_number ,
    hire_date ,
    job_id ,
    salary ,
    commission_pct ,
    manager_id ,
    department_id
  )
SELECT
  EMPLOYEES.EMPLOYEE_ID ,
  EMPLOYEES.FIRST_NAME ,
  EMPLOYEES.LAST_NAME ,
  EMPLOYEES.EMAIL ,
  EMPLOYEES.PHONE_NUMBER ,
  EMPLOYEES.HIRE_DATE ,
  EMPLOYEES.JOB_ID ,
  EMPLOYEES.SALARY ,
  EMPLOYEES.COMMISSION_PCT ,
  EMPLOYEES.MANAGER_ID ,
  EMPLOYEES.DEPARTMENT_ID
FROM
  workspace.hr.employees AS EMPLOYEES;

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
#
# - Oracle hints `/*+ APPEND PARALLEL */` have been removed as they are not applicable in Databricks Spark SQL.
# - Schema and table names have been converted to lowercase and prefixed with `workspace.` following the naming conventions (e.g., `HR.TRG_EMP` -> `workspace.hr.trg_emp`).
# - The original ODI source did not contain any explicit `CREATE TABLE` statements for `HR.TRG_EMP`. Ensure the target table `workspace.hr.trg_emp` exists and has the correct schema (column names and data types) in Databricks Delta Lake before executing this INSERT statement.
# - Column names in the `INSERT` clause have been lowercased for consistency with Spark SQL best practices, though Spark is generally case-insensitive for identifiers by default.
