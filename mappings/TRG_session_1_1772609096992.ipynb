# %% [markdown]
# # ODI to Databricks Migration
# ## Insert into TRG_EMP
# Converted from `TARGET.sql`
# Conversion Timestamp: <current_timestamp>

# %%
dbutils.widgets.text("ETL_JOB_TYPE", "")
dbutils.widgets.text("DATASOURCE_NUM_ID", "")
dbutils.widgets.text("ETL_PROC_WID", "")
dbutils.widgets.text("ODI_SESS_NO", "")

# %% [markdown]
# ## ETL Parameters

# %%
display(spark.sql("""
SELECT
  '${ETL_JOB_TYPE}' AS ETL_JOB_TYPE,
  '${DATASOURCE_NUM_ID}' AS DATASOURCE_NUM_ID,
  '${ETL_PROC_WID}' AS ETL_PROC_WID,
  '${ODI_SESS_NO}' AS ODI_SESS_NO
"""))

# %% [markdown]
# ## SCEN_TASK_NO {30}: Insert into Target Table

# %%
# %sql
-- SCEN_TASK_NO in {10}
-- SCEN_TASK_NO in {20}
-- SCEN_TASK_NO in {30}
INSERT INTO workspace.hr.trg_emp
(
  employee_id,
  first_name,
  last_name,
  email,
  phone_number,
  hire_date,
  job_id,
  salary,
  commission_pct,
  manager_id,
  department_id
)
SELECT
  employees.employee_id,
  employees.first_name,
  employees.last_name,
  employees.email,
  employees.phone_number,
  employees.hire_date,
  employees.job_id,
  employees.salary,
  employees.commission_pct,
  employees.manager_id,
  employees.department_id
FROM
  workspace.hr.employees AS employees;

# %% [markdown]
# ## Cleanup

# %% [markdown]
# ## Validation

# %%
# %sql
SELECT COUNT(*) FROM workspace.hr.trg_emp;

# %% [markdown]
# ## Conversion Notes and Manual Actions Required
# This notebook was automatically converted from an ODI SQL script.
#
# *   The target table `workspace.hr.trg_emp` is assumed to exist with a compatible schema. If not, a `CREATE TABLE` statement based on the source `workspace.hr.employees` schema is required, ensuring Oracle data types are mapped to Spark SQL types (e.g., `NUMBER(p,0)` to `BIGINT`, `DATE` to `TIMESTAMP`, `VARCHAR2` to `STRING`).
# *   No specific ODI parameters were found in the original script, so placeholder widgets have been created.
