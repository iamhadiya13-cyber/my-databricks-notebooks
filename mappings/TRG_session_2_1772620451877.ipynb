# %% [markdown]
# # odi_sql_insert_example.sql to Databricks Spark SQL Notebook
#
# **Conversion Timestamp:** 2024-07-30 12:00:00 UTC
#
# **Description:** Converts a basic ODI SQL insert statement into a Databricks Spark SQL notebook. This includes schema and table naming conventions.

# %%
dbutils.widgets.text("ETL_JOB_TYPE", "", "ETL Job Type")
dbutils.widgets.text("DATASOURCE_NUM_ID", "", "Datasource Number ID")
dbutils.widgets.text("ETL_PROC_WID", "", "ETL Process ID")
dbutils.widgets.text("ODI_SESS_NO", "", "ODI Session Number")

# %% [markdown]
# ## ETL Parameters

# %%
# %sql
-- SCEN_TASK_NO in {10}: Initial setup tasks (no DML/DDL in source)
-- SCEN_TASK_NO in {20}: More setup tasks (no DML/DDL in source)
-- SCEN_TASK_NO in {30}: Further setup tasks (no DML/DDL in source)

# %% [markdown]
# ## MERGE into Target

# %%
# %sql
INSERT
  INTO workspace.hr.trg_dep
  (
    DEPARTMENT_ID ,
    DEPARTMENT_NAME ,
    MANAGER_ID ,
    LOCATION_ID
  )
SELECT
  DEPARTMENTS.DEPARTMENT_ID ,
  DEPARTMENTS.DEPARTMENT_NAME ,
  DEPARTMENTS.MANAGER_ID ,
  DEPARTMENTS.LOCATION_ID
FROM
  workspace.hr.departments AS DEPARTMENTS;

# %% [markdown]
# ## Cleanup
#
# No temporary staging or flow tables were used in this conversion, so no explicit cleanup actions are required for them. Persistent error tables, if any, would be handled by session-based deletion.

# %% [markdown]
# ## Validation
#
# No specific validation steps were provided in the source ODI SQL. Common validation steps would include record counts, data sampling, and error table checks.

# %% [markdown]
# ## Conversion Notes
#
# - **Oracle Hints:** The `/*+ APPEND PARALLEL */` Oracle hint has been removed as it is not applicable to Databricks Spark SQL.
# - **Schema Naming:** Oracle schema `HR` has been converted to `workspace.hr` to align with Databricks naming conventions.
# - **Table Naming:** Table names `TRG_DEP` and `DEPARTMENTS` have been converted to lowercase `trg_dep` and `departments` respectively.
# - **SCEN_TASK_NO Markers:** Empty `SCEN_TASK_NO` markers (e.g., `{10}`, `{20}`, `{30}`) have been preserved as comments within a SQL cell, as they did not contain executable DML/DDL.
# - **Widgets:** Standard ETL parameter widgets (`ETL_JOB_TYPE`, `DATASOURCE_NUM_ID`, `ETL_PROC_WID`, `ODI_SESS_NO`) have been included as placeholders, although they were not explicitly used in this particular simple INSERT statement.
