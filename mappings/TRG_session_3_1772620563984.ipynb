# %% [markdown]
# # ODI to Databricks Migration: `target.sql`
#
# **Conversion Timestamp:** 2024-07-30T12:00:00Z
#
# This notebook contains the converted Spark SQL logic from the original ODI session file `target.sql`. It performs a direct insert into the `TRG_LOC` table from the `LOCATIONS` table.

# %% [markdown]
# # Core ETL Logic

# %%
# %sql
-- SCEN_TASK_NO in {10}
-- SCEN_TASK_NO in {20}
-- SCEN_TASK_NO in {30}
INSERT INTO workspace.hr.trg_loc
(
  location_id,
  street_address,
  postal_code,
  city,
  state_province,
  country_id
)
SELECT
  locations.location_id,
  locations.street_address,
  locations.postal_code,
  locations.city,
  locations.state_province,
  locations.country_id
FROM
  workspace.hr.locations AS locations;

# %% [markdown]
# # Validation

# %%
# %sql
SELECT COUNT(*) AS total_records_inserted
FROM workspace.hr.trg_loc;

# %% [markdown]
# # Conversion Notes

# %% [markdown]
# 1.  **Oracle Hints Removed:** The `/*+ APPEND PARALLEL */` hint has been removed as it is Oracle-specific and not applicable to Databricks Delta Lake.
# 2.  **Schema and Table Naming:** Oracle schema `HR` and tables `TRG_LOC`, `LOCATIONS` have been converted to lowercase and prefixed with `workspace.` following the naming convention: `workspace.hr.trg_loc` and `workspace.hr.locations`.
# 3.  **SCEN_TASK_NO:** The ODI `SCEN_TASK_NO` comments have been preserved within the relevant SQL cell for traceability, as they represented setup tasks for the insert operation.
